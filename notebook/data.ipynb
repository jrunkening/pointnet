# %%
from pointnet.data import ModelNet40H5

# %%
dataset = ModelNet40H5(phase="train", data_root="../data")
# import glob
# from pathlib import Path

# len(glob.glob(Path("../data").joinpath("modelnet40_ply_hdf5_2048/").as_posix()))
# Out:
# ...
# --2023-07-15 12:02:27--  https://shapenet.cs.stanford.edu/media/modelnet40_ply_hdf5_2048.zip
# Loaded CA certificate '/etc/ssl/certs/ca-certificates.crt'
# Resolving shapenet.cs.stanford.edu (shapenet.cs.stanford.edu)... 171.67.77.19
# Connecting to shapenet.cs.stanford.edu (shapenet.cs.stanford.edu)|171.67.77.19|:443... connected.
# WARNING: The certificate of ‘shapenet.cs.stanford.edu’ is not trusted.
# WARNING: The certificate of ‘shapenet.cs.stanford.edu’ has expired.
# The certificate has expired
# HTTP request sent, awaiting response... 200 OK
# Length: 435212151 (415M) [application/zip]
# Saving to: ‘../data/modelnet40_ply_hdf5_2048.zip’
#
#      0K .......... .......... .......... .......... ..........  0%  116K 61m17s
#     50K .......... .......... .......... .......... ..........  0%  117K 60m52s
#    100K .......... .......... .......... .......... ..........  0%  352K 47m17s
#    150K .......... .......... .......... .......... ..........  0%  176K 45m31s
# ...
